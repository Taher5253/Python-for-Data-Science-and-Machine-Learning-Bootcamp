# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
# ** NOTE: This project is extremely challenging because it will introduce a lot of new concepts and have you looking things up on your own (we'll point you in the right direction) to try to solve the tasks issued. Feel free to just go through the solutions lecture notebook and video as a "walkthrough" project if you don't want to have to look things up yourself. You'll still learn a lot that way! **
# ____
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Google finance using pandas!
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# *Note: [You'll need to install pandas-datareader for this to work!](https://github.com/pydata/pandas-datareader) Pandas datareader allows you to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**), or just follow along with the video lecture.*
#
# ### The Imports
#
# Already filled out for you.

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
# ** Use [this documentation page](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) for hints and instructions (it should just be a matter of replacing certain values. Use google finance as a source, for example:**
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)
#
# ### WARNING: MAKE SURE TO CHECK THE LINK ABOVE FOR THE LATEST WORKING API. "google" MAY NOT ALWAYS WORK.
# ------------
# ### We also provide pickle file in the article lecture right before the video lectures.

# %%
bac = df.xs(("Close", "C"), level=("Stock Info", "Bank Ticker"), axis=1)
print(len(bac))
list1 = []
print(bac.iloc[1]/bac.iloc[0]-1)
count = 0
for x in range(len(bac)):
    if x==0:
        list1.append('nan')
        #count = count+1
    else:
        #print(count)
        tt= bac.iloc[count+1]/bac.iloc[count]-1
        count = count+1
        list1.append(tt)
print(list1)

dfreturn1 = pd.DataFrame(list(list1),columns =['C Return'])

dfreturn1['Date']=dataWFC.index.values
dfreturn = dfreturn.set_index('Date')

#dfreturn['Date']=dataWFC.index.values
dfreturn
# Out:
# 2517
# Bank Ticker  Stock Info
# C            Close        -0.018462
# dtype: float64
# ['nan', Bank Ticker  Stock Info
# C            Close        -0.018462
# dtype: float64, Bank Ticker  Stock Info
# C            Close         0.004961
# dtype: float64, Bank Ticker  Stock Info
# C            Close         0.0
# dtype: float64, Bank Ticker  Stock Info
# C            Close        -0.004731
# dtype: float64, Bank Ticker  Stock Info
# C            Close         0.0031
# dtype: float64, Bank Ticker  Stock Info
# C            Close         0.009065
# dtype: float64, Bank Ticker  Stock Info
# C            Close         0.001021
# dtype: float64, Bank Ticker  Stock Info
# C            Close        -0.002244
# dtype: float64, Bank Ticker  Stock Info
# C            Close        -0.010016
# dtype: float64, Bank Ticker  Stock Info
# C            Close        -0.001032
# dtype: float64, Bank Ticker  Stock Info
# C            Close        -0.009095
# dtype: float64, Bank Ticker  Stock Info
# ...

# %%
df = pd.read_pickle('all_banks') 
df
# Out:
# Bank Ticker    BAC                                      C                  \
# Stock Info    Open   High    Low  Close    Volume    Open    High     Low
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.00  493.80  481.10
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.60  491.00  483.50
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.40  487.80  484.00
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.80  489.00  482.00
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.00  487.40  483.00
# ...            ...    ...    ...    ...       ...     ...     ...     ...
# 2015-12-24   17.32  17.38  17.22  17.27  29373415   52.48   52.97   52.45
# 2015-12-28   17.22  17.23  16.98  17.13  41777497   52.57   52.57   51.96
# 2015-12-29   17.25  17.35  17.16  17.28  45670376   52.76   53.22   52.74
# 2015-12-30   17.20  17.24  17.04  17.05  35066378   52.84   52.94   52.25
# 2015-12-31   17.01  17.07  16.83  16.83  47152968   52.07   52.39   51.75
#
# ...

# %%
# import pandas_datareader.data as web
# from datetime import datetime

# start = datetime(2016, 9, 1)
# end   = datetime(2018, 9, 1)

# f = web.DataReader('BAC', 'yahoo', start, end)
# print(f)

# aapl = data.DataReader("AAPL", 
#                        start='2015-1-1', 
#                        end='2015-12-31', 
#                        data_source='yahoo')

# aapl

from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe databac
databac = pdr.get_data_yahoo("BAC", start="2006-1-1", end="2016-1-1")

print(databac)


# download dataframe datac 

datac = pdr.get_data_yahoo("C", start="2006-1-1", end="2016-1-1")

print(datac)

## download dataframe dataGS

dataGS = pdr.get_data_yahoo("GS", start="2006-1-1", end="2016-1-1")

print(dataGS)


## download dataframe dataJPM

dataJPM = pdr.get_data_yahoo("JPM", start="2006-1-1", end="2016-1-1")

print(dataJPM)

## download dataframe dataMS

dataMS = pdr.get_data_yahoo("MS", start="2006-1-1", end="2016-1-1")

print(dataMS)

## download dataframe dataWFC

 
dataWFC = pdr.get_data_yahoo("WFC", start="2006-1-1", end="2016-1-1")

print(dataWFC)
print(dataWFC.index.values)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  33.942669  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  33.582169  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  33.625423  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  33.574966  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  33.596596  15619400
# ...               ...        ...        ...        ...        ...       ...
# 2015-12-24  17.320000  17.379999  17.219999  17.270000  15.356144  29369400
# 2015-12-28  17.219999  17.230000  16.980000  17.129999  15.231658  41777500
# 2015-12-29  17.250000  17.350000  17.160000  17.280001  15.365039  45670400
# 2015-12-30  17.200001  17.240000  17.040001  17.049999  15.160524  35066400
# ...

# %%
#from datetime import datetime

#start = datetime(2016, 9, 1)
#end   = datetime(2018, 9, 1)

#f = data.DataReader('BAC', 'quandl', start, end)
#print(f)

aapl = data.DataReader("BAC", 
                       start='2006-1-1', 
                       end='2016-1-1', 
                       data_source='yahoo')
aapl
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  33.942669  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  33.582195  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  33.625439  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  33.574963  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  33.596588  15619400
# ...               ...        ...        ...        ...        ...       ...
# 2015-12-24  17.320000  17.379999  17.219999  17.270000  15.356150  29369400
# 2015-12-28  17.219999  17.230000  16.980000  17.129999  15.231661  41777500
# 2015-12-29  17.250000  17.350000  17.160000  17.280001  15.365040  45670400
# 2015-12-30  17.200001  17.240000  17.040001  17.049999  15.160522  35066400
# ...

# %%
#databac
marks_list = databac['Close'].tolist()
#marks_list
list111=[]
list11=[]
for i in marks_list:
    list11.append(round(i, 2))
#print(list11)
count=0
for x in range(len(marks_list)):
    if x==0:
        list111.append(np.nan)
        #count = count+1
    else:
        #print(count)
        tt= marks_list[count+1]/marks_list[count]-1
        count = count+1
        list111.append(tt)
#print(list1)

databac['BAC Return'] = list111
databac

#datac
marks_list2 = datac['Close'].tolist()
#marks_list
list22 = []
for i in marks_list2:
    list22.append(round(i, 2))
##print(list22)

list2=[]
count=0
for x in range(len(marks_list2)):
    if x==0:
        list2.append(np.nan)
        #count = count+1
    else:
        #print(count)
        tt= list22[count+1]/list22[count]-1
        count = count+1
        list2.append(tt)
#print(list1)

datac['C Return'] = list2
datac

#dataGS
marks_list3 = dataGS['Close'].tolist()
#marks_list
list3=[]
count=0
for x in range(len(marks_list3)):
    if x==0:
        list3.append(np.nan)
        #count = count+1
    else:
        #print(count)
        tt= marks_list3[count+1]/marks_list3[count]-1
        count = count+1
        list3.append(tt)
#print(list1)

dataGS['GS Return'] = list3
dataGS

#dataJPM
marks_list4 = dataJPM['Close'].tolist()
#marks_list
list4=[]
count=0
for x in range(len(marks_list4)):
    if x==0:
        list4.append(np.nan)
        #count = count+1
    else:
        #print(count)
        tt= marks_list4[count+1]/marks_list4[count]-1
        count = count+1
        list4.append(tt)
#print(list1)

dataJPM['JPM Return'] = list4
print(len(dataJPM))

#dataMS
marks_list5 = dataMS['Close'].tolist()
#marks_list
list5=[]
count=0
for x in range(len(marks_list5)):
    if x==0:
        list5.append(np.nan)
        #count = count+1
    else:
        #print(count)
        tt= marks_list5[count+1]/marks_list5[count]-1
        count = count+1
        list5.append(tt)
#print(list1)

dataMS['MS Return'] = list5
print(len(dataMS))


#dataWFC
marks_list6 = dataWFC['Close'].tolist()
#marks_list
list6=[]
count=0
for x in range(len(marks_list6)):
    if x==0:
        list6.append(np.nan)
        #count = count+1
    else:
        #print(count)
        tt= marks_list6[count+1]/marks_list6[count]-1
        count = count+1
        list6.append(tt)
#print(list1)

dataWFC['WFC Return'] = list6
print(len(dataWFC))




bac = df.xs(("Close", "C"), level=("Stock Info", "Bank Ticker"), axis=1)
mrlist = bac['C']['Close']
print(len(mrlist))
#print(marks_list2)
list222 = list2[1:]
#print(min(list222))
#print(min(marks_list2))

#dicy ={'BAC Return':list1,'C Return':list2,'GS Return':list3,'JPM Return':list4,'MS Return':list5,'WFC Return'}
#dfreturn.set_index('month')
#dataWFC.index.values

#print(dataWFC.index.values)

dfreturn = pd.DataFrame(list(zip(list111,list2,list3,list4,list5,list6)),
               columns =['BAC Return','C Return','GS Return','JPM Return','MS Return','WFC Return'])

dfreturn['Date']=dataWFC.index.values
print(len(dataWFC.index.values))
dfreturn = dfreturn.set_index('Date')

#dfreturn['Date']=dataWFC.index.values
#print(type(dfreturn['C Return'].iloc[1]))

#dataWFC
# Out:
# 2517
# 2517
# 2517
# 2517
# 2517

# %%
tickers = ["BAC","C","GS","JPM","MS","WFC"]

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
bank_stocks = pd.concat([databac,datac,dataGS,dataJPM,dataMS,dataWFC], axis=1, keys=tickers)
bank_stocks
bank_stocks['Date'] = bank_stocks.index.values
ee= bank_stocks['Date']
ee
# Out:
# Date
# 2006-01-03   2006-01-03
# 2006-01-04   2006-01-04
# 2006-01-05   2006-01-05
# 2006-01-06   2006-01-06
# 2006-01-09   2006-01-09
#                 ...
# 2015-12-24   2015-12-24
# 2015-12-28   2015-12-28
# 2015-12-29   2015-12-29
# 2015-12-30   2015-12-30
# 2015-12-31   2015-12-31
# Name: Date, Length: 2517, dtype: datetime64[ns]

# %%
bank_stocks.columns = bank_stocks.columns.rename("Stock Info", level=1)
bank_stocks.columns = bank_stocks.columns.rename("Bank Ticker", level=0)
bank_stocks
# Out:
# Bank Ticker        BAC                                                        \
# Stock Info        Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03   46.919998  47.180000  46.150002  47.080002  33.942657  16296700
# 2006-01-04   47.000000  47.240002  46.450001  46.580002  33.582180  17757900
# 2006-01-05   46.580002  46.830002  46.320000  46.639999  33.625435  14970700
# 2006-01-06   46.799999  46.910000  46.349998  46.570000  33.574970  12599800
# 2006-01-09   46.720001  46.970001  46.360001  46.599998  33.596600  15619400
# ...                ...        ...        ...        ...        ...       ...
# 2015-12-24   17.320000  17.379999  17.219999  17.270000  15.356145  29369400
# 2015-12-28   17.219999  17.230000  16.980000  17.129999  15.231662  41777500
# 2015-12-29   17.250000  17.350000  17.160000  17.280001  15.365035  45670400
# 2015-12-30   17.200001  17.240000  17.040001  17.049999  15.160527  35066400
# ...

# %% [markdown]
# ** Set the column name levels (this is filled out for you):**

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# ** Check the head of the bank_stocks dataframe.**

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                                        \
# Stock Info        Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03   46.919998  47.180000  46.150002  47.080002  33.942657  16296700
# 2006-01-04   47.000000  47.240002  46.450001  46.580002  33.582180  17757900
# 2006-01-05   46.580002  46.830002  46.320000  46.639999  33.625435  14970700
# 2006-01-06   46.799999  46.910000  46.349998  46.570000  33.574970  12599800
# 2006-01-09   46.720001  46.970001  46.360001  46.599998  33.596600  15619400
#
# Bank Ticker                      C                          ...       MS  \
# Stock Info  BAC Return        Open        High         Low  ...   Volume
# Date                                                        ...
# 2006-01-03         NaN  490.000000  493.799988  481.100006  ...  5377000
# 2006-01-04   -0.010620  488.600006  491.000000  483.500000  ...  7977800
# ...

# %%
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker             ...        MS                                  WFC  \
# Stock Info    Volume    ...      Open   High    Low  Close   Volume   Open
# Date                    ...
# 2006-01-03   1537660    ...     57.17  58.49  56.74  58.31  5377000  31.60
# 2006-01-04   1871020    ...     58.70  59.28  58.35  58.35  7977800  31.80
# 2006-01-05   1143160    ...     58.55  58.59  58.02  58.51  5778000  31.50
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit! Before continuing, I encourage you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Reference the solutions if you can not figure out how to use .xs(), since that will be a major part of this project.
#
# ** What is the max Close price for each bank's stock throughout the time period?**

# %%
#bank_stocks.xs('Bank Ticker', level=0)
#tickers = ["BAC","C","GS","JPM","MS","WFC"]
bac = bank_stocks.xs(("Close", "BAC"), level=("Stock Info", "Bank Ticker"), axis=1).max()
print(bac)
c = bank_stocks.xs(("Close", "C"), level=("Stock Info", "Bank Ticker"), axis=1).max()
print(c)
gs = bank_stocks.xs(("Close", "GS"), level=("Stock Info", "Bank Ticker"), axis=1).max()
print(gs)
JPM = bank_stocks.xs(("Close", "JPM"), level=("Stock Info", "Bank Ticker"), axis=1).max()
print(JPM)
MS = bank_stocks.xs(("Close", "MS"), level=("Stock Info", "Bank Ticker"), axis=1).max()
print(MS)
WFC = bank_stocks.xs(("Close", "WFC"), level=("Stock Info", "Bank Ticker"), axis=1).max()
print(WFC)
# Out:
# Bank Ticker  Stock Info
# BAC          Close         54.900002
# dtype: float64
# Bank Ticker  Stock Info
# C            Close         564.099976
# dtype: float64
# Bank Ticker  Stock Info
# GS           Close         247.919998
# dtype: float64
# Bank Ticker  Stock Info
# JPM          Close         70.080002
# dtype: float64
# Bank Ticker  Stock Info
# MS           Close         89.300003
# dtype: float64
# Bank Ticker  Stock Info
# WFC          Close         58.52
# dtype: float64

# %%
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
bac = bank_stocks.xs(("Close", "BAC"), level=("Stock Info", "Bank Ticker"), axis=1)
print(len(bac))
list1 = []
print(bac.iloc[1]/bac.iloc[0]-1)
count = 0
for x in range(len(bac)):
    if x==0:
        list1.append('nan')
        #count = count+1
    else:
        #print(count)
        tt= bac.iloc[count+1]/bac.iloc[count]-1
        count = count+1
        list1.append(tt)
print(list1)

# Declare a list that is to be converted into a column
address = ['Delhi', 'Bangalore', 'Chennai', 'Patna']
  
# Using 'Address' as the column name
# and equating it to the list
bank_stocks['BAC']['return'] = list1
# Out:
# 2517
# Bank Ticker  Stock Info
# BAC          Close        -0.01062
# dtype: float64
# ['nan', Bank Ticker  Stock Info
# BAC          Close        -0.01062
# dtype: float64, Bank Ticker  Stock Info
# BAC          Close         0.001288
# dtype: float64, Bank Ticker  Stock Info
# BAC          Close        -0.001501
# dtype: float64, Bank Ticker  Stock Info
# BAC          Close         0.000644
# dtype: float64, Bank Ticker  Stock Info
# BAC          Close        -0.008369
# dtype: float64, Bank Ticker  Stock Info
# BAC          Close        -0.00238
# dtype: float64, Bank Ticker  Stock Info
# BAC          Close        -0.006508
# dtype: float64, Bank Ticker  Stock Info
# BAC          Close         0.0
# dtype: float64, Bank Ticker  Stock Info
# BAC          Close        -0.010699
# dtype: float64, Bank Ticker  Stock Info
# BAC          Close        -0.001104
# dtype: float64, Bank Ticker  Stock Info
# BAC          Close        -0.002651
# dtype: float64, Bank Ticker  Stock Info
# ...

# %%
# Declare a list that is to be converted into a column
address = ['Delhi', 'Bangalore', 'Chennai', 'Patna']
  
# Using 'Address' as the column name
# and equating it to the list
bank_stocks['BAC']['return'] = address
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-f7f4bf786b7a> in <module>
#       4 # Using 'Address' as the column name
#       5 # and equating it to the list
# ----> 6 bank_stocks['BAC']['return'] = address
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# ...

# %%
bank_stocks.set_index('Date').diff()
# Out:
# Bank Ticker       BAC                                                      \
# Stock Info       Open      High       Low     Close Adj Close      Volume
# Date
# 2006-01-03        NaN       NaN       NaN       NaN       NaN         NaN
# 2006-01-04   0.080002  0.060001  0.299999 -0.500000 -0.360477   1461200.0
# 2006-01-05  -0.419998 -0.410000 -0.130001  0.059998  0.043255  -2787200.0
# 2006-01-06   0.219997  0.079998  0.029999 -0.070000 -0.050465  -2370900.0
# 2006-01-09  -0.079998  0.060001  0.010002  0.029999  0.021629   3019600.0
# ...               ...       ...       ...       ...       ...         ...
# 2015-12-24   0.160000  0.039999  0.119999 -0.070000 -0.062244 -36401300.0
# 2015-12-28  -0.100000 -0.150000 -0.240000 -0.140001 -0.124483  12408100.0
# 2015-12-29   0.030001  0.120001  0.180000  0.150002  0.133373   3892900.0
# 2015-12-30  -0.049999 -0.110001 -0.119999 -0.230001 -0.204508 -10604000.0
# 2015-12-31  -0.190001 -0.170000 -0.210001 -0.219999 -0.195621  12086600.0
#
# ...

# %% [markdown]
# ** We can use pandas pct_change() method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
dfreturn
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158
# ...                ...       ...        ...         ...        ...         ...
# 2015-12-24   -0.004037  0.001520  -0.002624   -0.001948  -0.003681   -0.003997
# 2015-12-28   -0.008107 -0.006261  -0.004658   -0.003303  -0.009544   -0.002554
# 2015-12-29    0.008757  0.011455   0.010516    0.010395   0.011812    0.011156
# 2015-12-30   -0.013310 -0.012835  -0.008282   -0.007157  -0.009831   -0.007235
# 2015-12-31   -0.012903 -0.010516  -0.009780   -0.008410  -0.013031   -0.009656
#
# ...

# %%
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
sns.pairplot(dfreturn)

# %% [markdown]
# * See solution for details about Citigroup behavior....

# %% [markdown]
# ** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
print(dfreturn.idxmax())
print(dfreturn.index[dfreturn['BAC Return']==dfreturn['BAC Return'].max()])
print(dfreturn.index[dfreturn['C Return']==dfreturn['C Return'].max()])
print(dfreturn.index[dfreturn['GS Return']==dfreturn['GS Return'].max()])
print(dfreturn.index[dfreturn['JPM Return']==dfreturn['JPM Return'].max()])
print(dfreturn.index[dfreturn['MS Return']==dfreturn['MS Return'].max()])
print(dfreturn.index[dfreturn['WFC Return']==dfreturn['WFC Return'].max()])
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]
# DatetimeIndex(['2009-04-09'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2008-11-24'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2008-11-24'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2009-01-21'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2008-10-13'], dtype='datetime64[ns]', name='Date', freq=None)
# DatetimeIndex(['2008-07-16'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
bac = df.xs(("Close", "BAC"), level=("Stock Info", "Bank Ticker"), axis=1)
mrlist = bac['BAC']['Close'].tolist()
#print(mrlist)

for i in range(len(mrlist)):
    if list11[i]==mrlist[i]:
        continue
    else:
        print('false')
        print(list11[i])
        print(mrlist[i])

list1 = []
print(bac.iloc[1]/bac.iloc[0]-1)
count = 0
for x in range(len(bac)):
    if x==0:
        list1.append(np.nan)
        #count = count+1
    else:
        #print(count)
        tt= bac['BAC']['Close'].iloc[count+1]/bac['BAC']['Close'].iloc[count]-1
        count = count+1
        list1.append(tt)
#print(list1)


for i in range(len(list111)):
    if list111[i]==list1[i]:
        continue
    else:
        print('false')
        print(list111[i])
        print(list1[i])

dfreturn1 = pd.DataFrame(list1,columns =['BAC Return'])

dfreturn1['Date']=dataWFC.index.values
dfreturn1 = dfreturn1.set_index('Date')

#dfreturn['Date']=dataWFC.index.values
print(dfreturn1['BAC Return'])
minvalue_series = dfreturn1.min(skipna = True)
print(min(list1))

print(minvalue_series)
# Out:
# false
# 45.26
# 45.18
# false
# 4.99
# 4.98
# false
# 5.29
# 5.28
# false
# 8.93
# 8.92
# false
# 12.25
# 12.24
# false
# 14.71
# 14.72
# Bank Ticker  Stock Info
# BAC          Close        -0.01062
# dtype: float64
# false
# nan
# nan
# false
# -0.010620220487548737
# -0.010620220900594779
# false
# 0.0012880540196491541
# 0.0012881064834693312
# false
# -0.00150085110935394
# -0.0015008576329330614
# false
# 0.0006441653316182627
# 0.0006441915396178111
# false
# -0.008369085888812244
# -0.008369098712446399
# false
# -0.00238045039019541
# -0.00238043713481928
# false
# -0.0065075758566229824
# -0.006507592190889477
# false
# -0.010698643491963922
# -0.01069868995633172
# false
# -0.0011035764785318758
# -0.0028691238137277253
# false
# -0.0026513242672321358
# -0.0008853474988933518
# false
# -0.021045652985925978
# -0.021045635799734175
# false
# -0.005204787268251132
# -0.005204797465489852
# false
# 0.006369485892301574
# 0.006369426751592355
# false
# 0.008815537406235308
# ...

# %%
#dfreturn.loc[dfreturn['BAC Return'].idxmax()]
dfreturn.index[dfreturn['BAC Return']==dfreturn['BAC Return'].min()]
#dfreturn1.index[dfreturn1['C Return']==dfreturn1['C Return'].max()]
#dfreturn.index[dfreturn['GS Return']==dfreturn['GS Return'].min()]
#dfreturn.index[dfreturn['JPM Return']==dfreturn['JPM Return'].min()]
#dfreturn.index[dfreturn['MS Return']==dfreturn['MS Return'].min()]
#dfreturn.index[dfreturn['WFC Return']==dfreturn['WFC Return'].min()]
# Out:
# DatetimeIndex(['2009-01-20'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
# Out:
# BAC Return   2009-01-20
# C Return     2011-05-06
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %% [markdown]
# * See Solution for details

# %%
# Out:
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ** Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
dfreturn
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158
# ...                ...       ...        ...         ...        ...         ...
# 2015-12-24   -0.004037  0.001520  -0.002624   -0.001948  -0.003681   -0.003997
# 2015-12-28   -0.008107 -0.006261  -0.004658   -0.003303  -0.009544   -0.002554
# 2015-12-29    0.008757  0.011455   0.010516    0.010395   0.011812    0.011156
# 2015-12-30   -0.013310 -0.012835  -0.008282   -0.007157  -0.009831   -0.007235
# 2015-12-31   -0.012903 -0.010516  -0.009780   -0.008410  -0.013031   -0.009656
#
# ...

# %%
# Convert the date to datetime64
#dfreturn['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
  
# Filter data between two dates
#filtered_df = df.loc[(df['date'] >= '2020-09-01')& (df['date'] < '2020-09-15')]
# Display
#filtered_df

dfreturn = dfreturn.reset_index()
#dfreturn.iloc[0]
dfreturn['Date'] = pd.to_datetime(dfreturn['Date'], format='%Y-%m-%d')
filtered_df = dfreturn.loc[(dfreturn['Date'] >= '2015-01-01')& (dfreturn['Date'] <= '2015-12-31')]
filtered_df
print(filtered_df['C Return'].std())
print(filtered_df['BAC Return'].std())
print(filtered_df['GS Return'].std())
print(filtered_df['JPM Return'].std())
print(filtered_df['MS Return'].std())
print(filtered_df['WFC Return'].std())
#print(type(dfreturn['Date']))
# Out:
# 0.015289388143030559
# 0.016162568742018806
# 0.014046398556986656
# 0.014016841928251957
# 0.01624911717000169
# 0.012591404257112995

# %%
print(dfreturn['C Return'].std())
print(dfreturn['BAC Return'].std())
print(dfreturn['GS Return'].std())
print(dfreturn['JPM Return'].std())
print(dfreturn['MS Return'].std())
print(dfreturn['WFC Return'].std())
# Out:
# 0.03867175192090029
# 0.03664742891135391
# 0.025389763771044502
# 0.027667384258985763
# 0.03781922911717958
# 0.030237538357458068

# %%
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %%
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# ** Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
x= dfreturn['MS Return']
sns.distplot(x,)
# Out:
# /home/taher/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MS Return', ylabel='Density'>

# %%
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
dfreturn['Date'] = pd.to_datetime(dfreturn['Date'], format='%Y-%m-%d')
filtered_df = dfreturn.loc[(dfreturn['Date'] >= '2008-01-01')& (dfreturn['Date'] <= '2008-12-31')]
filtered_df
d= dfreturn['C Return']
sns.distplot(d,bins=530)
# Out:
# /home/taher/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='C Return', ylabel='Density'>

# %%
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
# loading dataset
#data = sns.load_dataset("iris")
plt.figure(figsize=(13,4))
bac = bank_stocks.xs(("Close", "BAC"), level=("Stock Info", "Bank Ticker"), axis=1)


c = bank_stocks.xs(("Close", "C"), level=("Stock Info", "Bank Ticker"), axis=1)
gs = bank_stocks.xs(("Close", "GS"), level=("Stock Info", "Bank Ticker"), axis=1)
ms = bank_stocks.xs(("Close", "MS"), level=("Stock Info", "Bank Ticker"), axis=1)
jpm = bank_stocks.xs(("Close", "JPM"), level=("Stock Info", "Bank Ticker"), axis=1)
wfc = bank_stocks.xs(("Close", "WFC"), level=("Stock Info", "Bank Ticker"), axis=1)
# draw lineplot
sns.lineplot(x="Date", y=bac['BAC']['Close'].tolist(), data=bank_stocks)
sns.lineplot(x="Date", y=c['C']['Close'].tolist(), data=bank_stocks)
sns.lineplot(x="Date", y=gs['GS']['Close'].tolist(), data=bank_stocks)
sns.lineplot(x="Date", y=ms['MS']['Close'].tolist(), data=bank_stocks)
sns.lineplot(x="Date", y=jpm['JPM']['Close'].tolist(), data=bank_stocks)
sns.lineplot(x="Date", y=wfc['WFC']['Close'].tolist(), data=bank_stocks)
plt.show()

# %%
bac = bank_stocks.xs(("Close", "BAC"), level=("Stock Info", "Bank Ticker"), axis=1)
list_bac = bac['BAC']['Close']

# Define a dictionary containing Students data
#data = {'BAC Close': list_bac}
  
# Convert the dictionary into DataFrame
#dfreturn2 = pd.DataFrame(data)
#dfreturn2['Date']=dataWFC.index.values

#dfreturn2["BAC"]="BAC"
#dfreturn2


c = bank_stocks.xs(("Close", "C"), level=("Stock Info", "Bank Ticker"), axis=1)
list_c = c['C']['Close']

# Define a dictionary containing Students data
#data = {'C Close': list_c}
  
# Convert the dictionary into DataFrame
#dfreturn3 = pd.DataFrame(data)


#dfreturn3["C"]="C"
#dfreturn3

gs = bank_stocks.xs(("Close", "GS"), level=("Stock Info", "Bank Ticker"), axis=1)
list_gs = gs['GS']['Close']

# Define a dictionary containing Students data
#data = {'GS Close': list_gs}
  
# Convert the dictionary into DataFrame
#dfreturn4 = pd.DataFrame(data)


#dfreturn4["GS"]="GS"
#dfreturn4

data = {'BAC Close': list_bac, 'GS Close': list_gs, 'C Close': list_c}
dfreturn2 = pd.DataFrame(data)
#dfreturn2
dfreturn2["C"]="C"
dfreturn2["BAC"]="BAC"
dfreturn2["GS"]="GS"
dfreturn2
# Out:
#             BAC Close    GS Close     C Close  C  BAC  GS
# Date
# 2006-01-03  47.080002  128.869995  492.899994  C  BAC  GS
# 2006-01-04  46.580002  127.089996  483.799988  C  BAC  GS
# 2006-01-05  46.639999  127.040001  486.200012  C  BAC  GS
# 2006-01-06  46.570000  128.839996  486.200012  C  BAC  GS
# 2006-01-09  46.599998  130.389999  483.899994  C  BAC  GS
# ...               ...         ...         ... ..  ...  ..
# 2015-12-24  17.270000  182.470001   52.709999  C  BAC  GS
# 2015-12-28  17.129999  181.619995   52.380001  C  BAC  GS
# 2015-12-29  17.280001  183.529999   52.980000  C  BAC  GS
# 2015-12-30  17.049999  182.009995   52.299999  C  BAC  GS
# 2015-12-31  16.830000  180.229996   51.750000  C  BAC  GS
#
# [2517 rows x 6 columns]

# %%
sns.lineplot(x="Date", y="BAC Close",color='red', data=dfreturn2, hue = "BAC")
sns.lineplot(x="Date", y="C Close", data=dfreturn2, hue = "C")
sns.lineplot(x="Date", y="GS Close", data=dfreturn2, hue = "GS")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='BAC Close'>

# %%
# Out:
# <div id="16023fe4-0ed5-4915-a2b7-5e2290f9cf2e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("16023fe4-0ed5-4915-a2b7-5e2290f9cf2e", [{"type": "scatter", "x": ["2006-01-03", "2006-01-04", "2006-01-05", "2006-01-06", "2006-01-09", "2006-01-10", "2006-01-11", "2006-01-12", "2006-01-13", "2006-01-17", "2006-01-18", "2006-01-19", "2006-01-20", "2006-01-23", "2006-01-24", "2006-01-25", "2006-01-26", "2006-01-27", "2006-01-30", "2006-01-31", "2006-02-01", "2006-02-02", "2006-02-03", "2006-02-06", "2006-02-07", "2006-02-08", "2006-02-09", "2006-02-10", "2006-02-13", "2006-02-14", "2006-02-15", "2006-02-16", "2006-02-17", "2006-02-21", "2006-02-22", "2006-02-23", "2006-02-24", "2006-02-27", "2006-02-28", "2006-03-01", "2006-03-02", "2006-03-03", "2006-03-06", "2006-03-07", "2006-03-08", "2006-03-09", "200
# ...

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
#df['MA'] = df.rolling(window=5).mean()
#bank_stocks = bank_stocks.reset_index()
bank_stocks['Date'] = pd.to_datetime(bank_stocks['Date'], format='%Y-%m-%d')
filtered_df = bank_stocks.loc[(bank_stocks['Date'] >= '2008-01-01')& (bank_stocks['Date'] <= '2008-12-31')]
filtered_df
ss = filtered_df.xs(("Close", "BAC"), level=("Stock Info", "Bank Ticker"), axis=1)
dd = ss['BAC']['Close']
#sss= dd.iloc[1:]
#sss
ss['rolling_mean2'] = ss['BAC']['Close'].rolling(window=30).mean()
ss
#sns.distplot(d)
#d= dfreturn['C Return']
#sns.distplot(d)

sns.lineplot(x="Date", y=ss['BAC']['Close'], data=filtered_df)
sns.lineplot(x="Date", y=ss['rolling_mean2'], data=filtered_df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
bac = bank_stocks.xs(("Close", "BAC"), level=("Stock Info", "Bank Ticker"), axis=1)
list_bac = bac['BAC']['Close']

# Define a dictionary containing Students data
#data = {'BAC Close': list_bac}
  
# Convert the dictionary into DataFrame
#dfreturn2 = pd.DataFrame(data)
#dfreturn2['Date']=dataWFC.index.values

#dfreturn2["BAC"]="BAC"
#dfreturn2


c = bank_stocks.xs(("Close", "C"), level=("Stock Info", "Bank Ticker"), axis=1)
list_c = c['C']['Close']

# Define a dictionary containing Students data
#data = {'C Close': list_c}
  
# Convert the dictionary into DataFrame
#dfreturn3 = pd.DataFrame(data)


#dfreturn3["C"]="C"
#dfreturn3


gs = bank_stocks.xs(("Close", "GS"), level=("Stock Info", "Bank Ticker"), axis=1)
list_gs = gs['GS']['Close']


ms = bank_stocks.xs(("Close", "MS"), level=("Stock Info", "Bank Ticker"), axis=1)
list_ms = ms['MS']['Close']


jpm = bank_stocks.xs(("Close", "JPM"), level=("Stock Info", "Bank Ticker"), axis=1)
list_jpm = jpm['JPM']['Close']

wfc = bank_stocks.xs(("Close", "WFC"), level=("Stock Info", "Bank Ticker"), axis=1)
list_wfc = wfc['WFC']['Close']
# Define a dictionary containing Students data
#data = {'GS Close': list_gs}
  
# Convert the dictionary into DataFrame
#dfreturn4 = pd.DataFrame(data)


#dfreturn4["GS"]="GS"
#dfreturn4

data = {'BAC Close': list_bac, 'GS Close': list_gs, 'C Close': list_c, 'MS Close':list_ms, 'JPM Close':list_jpm, 'WFC Close': list_wfc}
dfreturn33 = pd.DataFrame(data)
dfreturn33

corrMatrix = dfreturn33.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# ** Optional: Use seaborn's clustermap to cluster the correlations together:**

# %%
sns.clustermap(corrMatrix,annot=True)

# %%
# Out:
# <div id="cfe3f8e3-825e-438f-9ede-9f7bd2e2ad65" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cfe3f8e3-825e-438f-9ede-9f7bd2e2ad65", [{"type": "heatmap", "x": ["BAC", "C", "GS", "JPM", "MS", "WFC"], "y": ["BAC", "C", "GS", "JPM", "MS", "WFC"], "colorscale": [[0.0, "rgb(165,0,38)"], [0.1, "rgb(215,48,39)"], [0.2, "rgb(244,109,67)"], [0.3, "rgb(253,174,97)"], [0.4, "rgb(254,224,144)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(224,243,248)"], [0.7, "rgb(171,217,233)"], [0.8, "rgb(116,173,209)"], [0.9, "rgb(69,117,180)"], [1.0, "rgb(49,54,149)"]], "z": [[1.0, 0.9715137697087325, 0.5509501372549771, 0.10389606365085878, 0.9442192943385206, 0.008566851425732356], [0.9715137697087325, 1.0, 0.4341706182992412, 0.003539648273630715, 0.9336049414173658, -0.06844121334375318], [0.5509501372549771, 0.43417061829
# ...

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
bank_stocks['Date'] = pd.to_datetime(bank_stocks['Date'], format='%Y-%m-%d')
filtered_df = bank_stocks.loc[(bank_stocks['Date'] >= '2015-01-01')& (bank_stocks['Date'] <= '2016-01-01')]
#filtered_df
ss = filtered_df.xs(("Close", "BAC"), level=("Stock Info", "Bank Ticker"), axis=1)
close_data = ss['BAC']['Close']
open_dta = filtered_df.xs(("Open", "BAC"), level=("Stock Info", "Bank Ticker"), axis=1)
open_data =  open_dta['BAC']['Open']
high_dta = filtered_df.xs(("High", "BAC"), level=("Stock Info", "Bank Ticker"), axis=1)
high_data = high_dta['BAC']['High']

low_dta = filtered_df.xs(("Low", "BAC"), level=("Stock Info", "Bank Ticker"), axis=1)
low_data = low_dta['BAC']['Low']
#low_data
date = filtered_df['Date']
data = {'close_data': close_data, 'open_data': open_data, 'high_data': high_data, 'low_data':low_data, 'Date':date}
dfreturn44 = pd.DataFrame(data)
dfreturn44
#ss

#filtered_df.iplot(kind='candle')
#.iplot(kind='bar',x='Category',y='Values')

import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=dfreturn44['Date'],
                open=dfreturn44['open_data'],
                high=dfreturn44['high_data'],
                low=dfreturn44['low_data'],
                close=dfreturn44['close_data'])])

fig.show()
# Out:
# <div>                            <div id="ba879519-c5c9-4f17-9593-fd45de38bd24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba879519-c5c9-4f17-9593-fd45de38bd24")) {                    Plotly.newPlot(                        "ba879519-c5c9-4f17-9593-fd45de38bd24",                        [{"close":[17.899999618530273,17.3799991607666,16.860000610351562,16.940000534057617,17.290000915527344,16.979999542236328,16.68000030517578,16.450000762939453,16.040000915527344,15.199999809265137,15.380000114440918,15.260000228881836,15.40999984741211,16.09000015258789,15.729999542236328,15.850000381469727,15.630000114440918,15.199999809265137,15.430000305175781,15.149999618530273,15.460000038146973,15.890000343322754,15.789999961853027,15.970000267028809,16.489
# ...

# %%
databac[['Open', 'High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01'].iplot(kind='candle')
# Out:
# <div>                            <div id="4c95b710-2458-4c2b-998c-719ea1bd5f35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
bank_stocks['Date'] = pd.to_datetime(bank_stocks['Date'], format='%Y-%m-%d')
filtered_df = bank_stocks.loc[(bank_stocks['Date'] >= '2015-01-01')& (bank_stocks['Date'] <= '2015-12-31')]
filtered_df
ss = filtered_df.xs(("Close", "MS"), level=("Stock Info", "Bank Ticker"), axis=1)
dd = ss['MS']['Close']
#sss= dd.iloc[1:]
#sss
ss['rolling_mean2'] = ss['MS']['Close'].rolling(window=30).mean()
ss
#sns.distplot(d)
#d= dfreturn['C Return']
#sns.distplot(d)

sns.lineplot(x="Date", y=ss['MS']['Close'], data=filtered_df)
sns.lineplot(x="Date", y=ss['rolling_mean2'], data=filtered_df)


#stockprices1 = {
  "stockprices_MA20": stockprices_MA20,
  "stockprices_20dSTD": stockprices_20dSTD,
  "stockprices_Upper": stockprices_Upper,
  "stockprices_Lower": stockprices_Lower
}

stockprices1['dd','stockprices_MA20','stockprices_Upper','stockprices_Lower'].plot(figsize=(10,4))
plt.grid(True)
plt.title(stock + ' Bollinger Bands')
plt.axis('tight')
plt.ylabel('Price')
plt.savefig('apple.png', bbox_inches='tight')
    
bollingerbands('aapl')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
MS['Close'].ix['2015-01-01':'2016-01-01'].ta_plot(study='sma',periods=[13,21,55],title='Simple Moving Averages')

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
import matplotlib.pyplot as plt

databac = pdr.get_data_yahoo("BAC", start="2015-1-1", end="2016-1-1")

#print(list(databac['Close']))
#print(databac.index.values)
# Create DataFrame
df1 = pd.DataFrame(list(databac['Close']), columns=['close'])
  
# Print the output.
df1['Date']=databac.index.values

df1 = df1.set_index('Date')
df1

df1['MA20'] = df1['close'].rolling(window=20).mean()
df1['20dSTD'] = df1['close'].rolling(window=20).std() 

df1['Upper'] = df1['MA20'] + (df1['20dSTD'] * 2)
df1['Lower'] = df1['MA20'] - (df1['20dSTD'] * 2)


df1[['close','MA20','Upper','Lower']].plot(figsize=(10,4))
plt.grid(True)
plt.title('Bollinger Bands')
plt.axis('tight')
plt.ylabel('Price')
#plt.savefig('apple.png', bbox_inches='tight')
    
#bollingerbands('aapl')
#df1['Date']=df1.index.values
#print(len(df1.index.values))
#df1 = df1.set_index('Date')
#df1['Date']=databac.index.values

#bank_stocks['Date'] = pd.to_datetime(bank_stocks['Date'], format='%Y-%m-%d')
#filtered_df = bank_stocks.loc[(bank_stocks['Date'] >= '2015-01-01')& (bank_stocks['Date'] <= '2015-12-31')]
#filtered_df
#ss = filtered_df.xs(("Close", "BAC"), level=("Stock Info", "Bank Ticker"), axis=1)
#print(ss)
#dd['Date']=filtered_df.index.values
#dd = dd.set_index('Date')
#print(bank_stocks['Date'])
#dd = ss['BAC']['Close']
#print(dd)
#print(ss['BAC']['Close'])

#dfreturn1['Date']=ss.index.values
#dfreturn1 = dfreturn1.set_index('Date')
#print(len(ss.index.values))

#dd['stockprices_MA20'] = dd.rolling(window=20).mean()
#dd['stockprices_20dSTD'] = dd.rolling(window=20).std() 

#dd['stockprices_Upper'] = dd['stockprices_MA20'] + (dd['stockprices_20dSTD'] * 2)
#dd['stockprices_Lower'] = dd['stockprices_MA20'] - (dd['stockprices_20dSTD'] * 2)
    

#print(type(dd))

#stockprices['Upper'] = stockprices['MA20'] + (stockprices['20dSTD'] * 2)
#stockprices['Lower'] = stockprices['MA20'] - (stockprices['20dSTD'] * 2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Text(0, 0.5, 'Price')

# %% [markdown]
# # Great Job!
#
# Definitely a lot of more specific finance topics here, so don't worry if you didn't understand them all! The only thing you should be concerned with understanding are the basic pandas and visualization oeprations.
